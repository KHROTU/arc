// %% [markdown]
// # Arc Playground Notebook
//
// This notebook demonstrates the notebook tools: `notebook.read`, `notebook.editCell`, `notebook.addCell`, `notebook.deleteCell`, and `notebook.execute`.

// %%
// Cell 1: Basic arithmetic
const a = 40;
const b = 2;
console.log(`a + b = ${a + b}`);
// Out:
// a + b = 42

// %%
// Cell 2: REPLACE_ME — this cell should be edited
const result = 'REPLACE_ME';
console.log(result);

// %% [markdown]
// ## Notes
//
// After fixing the REPLACE_ME in cell 2, use `notebook.execute` to run it.
